# %%
import pickle
from langchain_community.vectorstores import FAISS

# %%
pkl_path = "/home/pablo/Documentos/conversational-agent/agent/src/retrieval_graph/data/faiss/index.pkl"
faiss_path = "/home/pablo/Documentos/conversational-agent/agent/src/retrieval_graph/data/faiss/index.faiss"

# Cargar pickle
with open(pkl_path, "rb") as f:
    vectorstore: FAISS = pickle.load(f)

# Guardar como FAISS
vectorstore.save_local(faiss_path)
print("✅ Archivo FAISS guardado en", faiss_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       6     vectorstore: FAISS = pickle.load(f)
#       8 # Guardar como FAISS
# ----> 9 vectorstore.save_local(faiss_path)
#      10 print("✅ Archivo FAISS guardado en", faiss_path)
#
# AttributeError: 'tuple' object has no attribute 'save_local'
